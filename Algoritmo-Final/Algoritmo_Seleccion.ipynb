# %%
from Funcion import seleccion
import matplotlib.pyplot as plt

# %%
ruta = "C:/Users/juanm/OneDrive/Documentos/A_0/Universidad/Semilleros/Mecanica Aplicada/Reporte/G2_GW1_1_3.jpg"
raiz,filtro,porcentaje = seleccion(ruta)
plt.imshow(raiz, cmap=plt.cm.gray)

# %%
filtro
# Out:
# 5

# %%
porcentaje
# Out:
# 0.40086110134565617
